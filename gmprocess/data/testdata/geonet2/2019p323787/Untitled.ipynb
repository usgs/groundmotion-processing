# %%
# %matplotlib inline

# %%
from gmprocess.io.geonet.core import read_geonet

# %%
netfile = '20190430_191303_HUKS_20.V1A'
stream = read_geonet(netfile)[0]

# %%
fig = stream.plot(handle=True)
print(fig)
# Out:
# Figure(800x750)

# %%
trace = stream[0]
trace.times()
# Out:
# array([  0.00000000e+00,   5.00000000e-03,   1.00000000e-02, ...,
#          1.21075000e+02,   1.21080000e+02,   1.21085000e+02])
